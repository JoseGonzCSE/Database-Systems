# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/california-housing-feature-engineering/california.png
# /kaggle/input/california-housing-feature-engineering/cal_populations_city.csv
# /kaggle/input/california-housing-feature-engineering/cal_cities_lat_long.csv
# /kaggle/input/california-housing-feature-engineering/cal_populations_county.csv

# %%
city_pop = pd.read_csv("/kaggle/input/california-housing-feature-engineering/cal_populations_city.csv")

# %%
city_pop.shape
# Out:
# (455, 7)

# %%
city_pop.head()
# Out:
#            County          City Incorportation_date  pop_april_1980  \
# 0  San Bernardino      Adelanto                1970          2164.0
# 1     Los Angeles  Agoura Hills                1982             NaN
# 2         Alameda       Alameda                1854         63852.0
# 3         Alameda        Albany                1908         15130.0
# 4     Los Angeles      Alhambra                1903         64767.0
#
#    pop_april_1990  pop_april_2000  pop_april_2010
# 0            8517           18130           31765
# 1           20390           20537           20330
# 2           76459           72259           73812
# 3           16327           16444           18539
# 4           82106           85804           83089

# %%
city_pop["City"]
# Out:
# 0          Adelanto
# 1      Agoura Hills
# 2           Alameda
# 3            Albany
# 4          Alhambra
#            ...
# 450     Yorba Linda
# 451      Yountville
# 452           Yreka
# 453       Yuba City
# 454         Yucaipa
# Name: City, Length: 455, dtype: object

# %%
city_pop["City"][20]
# Out:
# 'Auburn'

# %%
city_pop.iloc[20]
# Out:
# County                 Placer
# City                   Auburn
# Incorportation_date      1888
# pop_april_1980           7540
# pop_april_1990          10592
# pop_april_2000          12462
# pop_april_2010          13330
# Name: 20, dtype: object

# %%
city_pop.iloc[20][1]
# Out:
# 'Auburn'

# %%
city_pop.loc[:10, ['City','County']]
# Out:
#             City          County
# 0       Adelanto  San Bernardino
# 1   Agoura Hills     Los Angeles
# 2        Alameda         Alameda
# 3         Albany         Alameda
# 4       Alhambra     Los Angeles
# 5        Alturas           Modoc
# 6    Amador City          Amador
# 7        Anaheim          Orange
# 8       Anderson          Shasta
# 9         Angels       Calaveras
# 10       Antioch    Contra Costa

# %%
city_pop.set_index("City")
# Out:
#                       County Incorportation_date  pop_april_1980  \
# City
# Adelanto      San Bernardino                1970          2164.0
# Agoura Hills     Los Angeles                1982             NaN
# Alameda              Alameda                1854         63852.0
# Albany               Alameda                1908         15130.0
# Alhambra         Los Angeles                1903         64767.0
# ...                      ...                 ...             ...
# Yorba Linda           Orange                1967         28254.0
# Yountville              Napa                1965          2893.0
# Yreka               Siskiyou                1857          5916.0
# Yuba City             Sutter                1908         18736.0
# Yucaipa       San Bernardino                1989             NaN
#
#               pop_april_1990  pop_april_2000  pop_april_2010
# City
# Adelanto                8517           18130           31765
# ...

# %%
city_pop.loc[city_pop.County == 'Merced']
# Out:
#      County        City Incorportation_date  pop_april_1980  pop_april_1990  \
# 19   Merced     Atwater                1922         17530.0           22282
# 106  Merced   Dos Palos                1935          3121.0            4196
# 154  Merced     Gustine                1915          3142.0            3931
# 213  Merced  Livingston                1922          5326.0            7317
# 224  Merced   Los Banos                1907         10341.0           14519
# 240  Merced      Merced                1889         36499.0           56216
#
#      pop_april_2000  pop_april_2010
# 19            23113           28168
# 106            4581            4950
# 154            4698            5520
# 213           10473           13058
# 224           25869           35972
# 240           63893           78958

# %%
city_pop['pop_april_2020'] = 0
city_pop.head()
# Out:
#            County          City Incorportation_date  pop_april_1980  \
# 0  San Bernardino      Adelanto                1970          2164.0
# 1     Los Angeles  Agoura Hills                1982             NaN
# 2         Alameda       Alameda                1854         63852.0
# 3         Alameda        Albany                1908         15130.0
# 4     Los Angeles      Alhambra                1903         64767.0
#
#    pop_april_1990  pop_april_2000  pop_april_2010  pop_april_2020
# 0            8517           18130           31765               0
# 1           20390           20537           20330               0
# 2           76459           72259           73812               0
# 3           16327           16444           18539               0
# 4           82106           85804           83089               0

# %%
city_pop.pop_april_2010.describe()
# Out:
# count    4.550000e+02
# mean     6.531554e+04
# std      2.036141e+05
# min      1.120000e+02
# 25%      1.065750e+04
# 50%      2.880600e+04
# 75%      6.676900e+04
# max      3.792621e+06
# Name: pop_april_2010, dtype: float64

# %%
city_pop.County.unique()
# Out:
# array(['San Bernardino', 'Los Angeles', 'Alameda', 'Modoc', 'Amador',
#        'Orange', 'Shasta', 'Calaveras', 'Contra Costa', 'Humboldt',
#        'San Luis Obispo', 'Kern', 'San Mateo', 'Merced', 'Placer',
#        'Kings', 'Riverside', 'Marin', 'Solano', 'Butte', 'Inyo',
#        'Imperial', 'Napa', 'Ventura', 'Santa Clara', 'Santa Cruz',
#        'San Diego', 'Monterey', 'Santa Barbara', 'Stanislaus', 'Madera',
#        'Sonoma', 'Fresno', 'Colusa', 'Tehama', 'Del Norte', 'Yolo',
#        'Tulare', 'Siskiyou', 'San Joaquin', 'Sacramento', 'Mendocino',
#        'Nevada', 'San Benito', 'Lake', 'Sutter', 'Sierra', 'Mono', 'Yuba',
#        'Glenn', 'El Dorado', 'Plumas', 'San Francisco', 'Tuolumne',
#        'Lassen'], dtype=object)

# %%
city_pop.County.value_counts()
# Out:
# Los Angeles        86
# Orange             29
# San Bernardino     22
# Riverside          21
# San Mateo          20
# Contra Costa       18
# San Diego          18
# Fresno             15
# Santa Clara        15
# Alameda            14
# Monterey           12
# Kern               11
# Marin              11
# Ventura            10
# Stanislaus          9
# Siskiyou            9
# Tulare              8
# Sonoma              8
# Solano              7
# Imperial            7
# San Joaquin         7
# San Luis Obispo     7
# Humboldt            7
# Merced              6
# Santa Barbara       6
# Placer              6
# Butte               5
# Amador              5
# Napa                4
# Mendocino           4
# Santa Cruz          4
# Kings               4
# Sacramento          4
# Yolo                4
# Tehama              3
# Glenn               2
# San Benito          2
# Sutter              2
# Yuba                2
# Nevada              2
# Shasta              2
# ...

# %%
city_pop.groupby('County').pop_april_2010.max()
# Out:
# County
# Alameda             390724
# Amador                7918
# Butte                86187
# Calaveras             3836
# Colusa                5971
# Contra Costa        122067
# Del Norte             7643
# El Dorado            21403
# Fresno              494665
# Glenn                 7291
# Humboldt             27191
# Imperial             42598
# Inyo                  3879
# Kern                347483
# Kings                53967
# Lake                  4753
# Lassen               17947
# Los Angeles        3792621
# Madera               61416
# Marin                57713
# Mendocino            16075
# Merced               78958
# Modoc                 2827
# Mono                  8234
# Monterey            150441
# Napa                 76915
# Nevada               12860
# Orange              336265
# Placer              118788
# Plumas                2104
# Riverside           303871
# Sacramento          466488
# San Benito           34928
# San Bernardino      209924
# ...

# %%
city_pop.groupby('County').pop_april_2010.max().sort_values()
# Out:
# County
# Sierra                 769
# Plumas                2104
# Modoc                 2827
# Calaveras             3836
# Inyo                  3879
# Lake                  4753
# Tuolumne              4903
# Colusa                5971
# Glenn                 7291
# Del Norte             7643
# Siskiyou              7765
# Amador                7918
# Mono                  8234
# Yuba                 12072
# Nevada               12860
# Tehama               14076
# Mendocino            16075
# Lassen               17947
# El Dorado            21403
# Humboldt             27191
# San Benito           34928
# Imperial             42598
# San Luis Obispo      45119
# Kings                53967
# Marin                57713
# Santa Cruz           59946
# Madera               61416
# Sutter               64925
# Yolo                 65622
# Napa                 76915
# Merced               78958
# Butte                86187
# Shasta               89861
# Santa Barbara        99553
# ...

# %%
city_pop.groupby(['County']).pop_april_2010.agg([min,max])
# Out:
#                     min      max
# County
# Alameda           10080   390724
# Amador              185     7918
# Butte              1707    86187
# Calaveras          3836     3836
# Colusa             5123     5971
# Contra Costa      10897   122067
# Del Norte          7643     7643
# El Dorado         10389    21403
# Fresno             4001   494665
# Glenn              6166     7291
# Humboldt            367    27191
# Imperial           2225    42598
# Inyo               3879     3879
# Kern               1154   347483
# Kings             15505    53967
# Lake               4753     4753
# Lassen            17947    17947
# Los Angeles         112  3792621
# Madera            18720    61416
# Marin              2068    57713
# Mendocino           449    16075
# Merced             4950    78958
# Modoc              2827     2827
# Mono               8234     8234
# Monterey            334   150441
# Napa               2933    76915
# Nevada             3068    12860
# ...

# %%
city_pop[pd.isnull(city_pop.pop_april_1980)]
# Out:
#              County              City Incorportation_date  pop_april_1980  \
# 1       Los Angeles      Agoura Hills                1982             NaN
# 11   San Bernardino      Apple Valley                1988             NaN
# 37   San Bernardino     Big Bear Lake                1980             NaN
# 61        Riverside    Cathedral City                1981             NaN
# 95           Orange        Dana Point                1989             NaN
# 102     Los Angeles       Diamond Bar                1989             NaN
# 111       San Mateo    East Palo Alto                1983             NaN
# 118       San Diego         Encinitas                1986             NaN
# 164  San Bernardino          Hesperia                1988             NaN
# 166  San Bernardino          Highland                1987             NaN
# 195       Riverside         La Quinta                1982             NaN
# 199          Orange     Laguna Niguel                1989             NaN
# ...

# %%
city_pop.rename(columns={'Incorportation_date': 'Incorporated', 'pop_april_1980' : 'pop_1980'})
# Out:
#              County          City Incorporated  pop_1980  pop_april_1990  \
# 0    San Bernardino      Adelanto         1970    2164.0            8517
# 1       Los Angeles  Agoura Hills         1982       NaN           20390
# 2           Alameda       Alameda         1854   63852.0           76459
# 3           Alameda        Albany         1908   15130.0           16327
# 4       Los Angeles      Alhambra         1903   64767.0           82106
# ..              ...           ...          ...       ...             ...
# 450          Orange   Yorba Linda         1967   28254.0           52422
# 451            Napa    Yountville         1965    2893.0            3259
# 452        Siskiyou         Yreka         1857    5916.0            6948
# 453          Sutter     Yuba City         1908   18736.0           27437
# 454  San Bernardino       Yucaipa         1989       NaN           32824
#
#      pop_april_2000  pop_april_2010  pop_april_2020
# ...

# %%
city_loc = pd.read_csv("/kaggle/input/california-housing-feature-engineering/cal_cities_lat_long.csv")
city_loc.head()
# Out:
#            Name   Latitude   Longitude
# 0      Adelanto  34.582769 -117.409214
# 1  Agoura Hills  34.153339 -118.761675
# 2       Alameda  37.765206 -122.241636
# 3        Albany  37.886869 -122.297747
# 4      Alhambra  34.095286 -118.127014

# %%
city_loc.set_index("Name")
city_pop.set_index("City")
# Out:
#                       County Incorportation_date  pop_april_1980  \
# City
# Adelanto      San Bernardino                1970          2164.0
# Agoura Hills     Los Angeles                1982             NaN
# Alameda              Alameda                1854         63852.0
# Albany               Alameda                1908         15130.0
# Alhambra         Los Angeles                1903         64767.0
# ...                      ...                 ...             ...
# Yorba Linda           Orange                1967         28254.0
# Yountville              Napa                1965          2893.0
# Yreka               Siskiyou                1857          5916.0
# Yuba City             Sutter                1908         18736.0
# Yucaipa       San Bernardino                1989             NaN
#
#               pop_april_1990  pop_april_2000  pop_april_2010  pop_april_2020
# City
# Adelanto                8517           18130           31765               0
# ...

# %%
city_pop.join(city_loc).head()
# Out:
#            County          City Incorportation_date  pop_april_1980  \
# 0  San Bernardino      Adelanto                1970          2164.0
# 1     Los Angeles  Agoura Hills                1982             NaN
# 2         Alameda       Alameda                1854         63852.0
# 3         Alameda        Albany                1908         15130.0
# 4     Los Angeles      Alhambra                1903         64767.0
#
#    pop_april_1990  pop_april_2000  pop_april_2010  pop_april_2020  \
# 0            8517           18130           31765               0
# 1           20390           20537           20330               0
# 2           76459           72259           73812               0
# 3           16327           16444           18539               0
# 4           82106           85804           83089               0
#
#            Name   Latitude   Longitude
# 0      Adelanto  34.582769 -117.409214
# 1  Agoura Hills  34.153339 -118.761675
# ...
